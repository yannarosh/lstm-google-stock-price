# %% [markdown]
# # Recurrent Neural Network

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

# %% [markdown]
# ### Importing the training set

# %%
# use just the open values from the dataset
train_og = pd.read_csv('data\Google_Stock_Price_Train.csv')
train = train_og.loc[:, 'Open'].values
train
# Out:
# array([325.25, 331.27, 329.83, ..., 793.7 , 783.33, 782.75])

# %% [markdown]
# ### Feature Scaling

# %%
# recommended to use normalization instead of standardization
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()

# reshape to 2d array
train = train.reshape(-1, 1)
train_sc = sc.fit_transform(train)
train_sc
# Out:
# array([[0.08581368],
#        [0.09701243],
#        [0.09433366],
#        ...,
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %% [markdown]
# ### Creating a data structure with 60 timesteps and 1 output

# %%
X_train=[]
y_train=[]

for timestamp in range(60, train_sc.shape[0]):
    y_train.append(train_sc[timestamp, 0])
    X_train.append(train_sc[timestamp-60: timestamp, 0]) #remember that the upper bound is excluded

#convert lists to arrays to use in the LSTM model.     
y_train = np.array(y_train)
X_train = np.array(X_train)

# %%
# sanity check
pd.DataFrame(X_train)
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.085814  0.097012  0.094334  0.091562  0.079842  0.064328  0.058542
# 1     0.097012  0.094334  0.091562  0.079842  0.064328  0.058542  0.065686
# 2     0.094334  0.091562  0.079842  0.064328  0.058542  0.065686  0.061091
# 3     0.091562  0.079842  0.064328  0.058542  0.065686  0.061091  0.066393
# 4     0.079842  0.064328  0.058542  0.065686  0.061091  0.066393  0.061426
# ...        ...       ...       ...       ...       ...       ...       ...
# 1193  0.934445  0.924939  0.921069  0.924381  0.930482  0.929905  0.931133
# 1194  0.924939  0.921069  0.924381  0.930482  0.929905  0.931133  0.927506
# 1195  0.921069  0.924381  0.930482  0.929905  0.931133  0.927506  0.944155
# 1196  0.924381  0.930482  0.929905  0.931133  0.927506  0.944155  0.938760
# 1197  0.930482  0.929905  0.931133  0.927506  0.944155  0.938760  0.934035
#
#             7         8         9   ...        50        51        52  \
# 0     0.065686  0.061091  0.066393  ...  0.052143  0.056124  0.058189
# 1     0.061091  0.066393  0.061426  ...  0.056124  0.058189  0.065407
# 2     0.066393  0.061426  0.074745  ...  0.058189  0.065407  0.068830
# 3     0.061426  0.074745  0.027978  ...  0.065407  0.068830  0.072438
# 4     0.074745  0.027978  0.023793  ...  0.068830  0.072438  0.079935
# ...        ...       ...       ...  ...       ...       ...       ...
# 1193  0.927506  0.944155  0.938760  ...  0.931766  0.941141  0.957623
# 1194  0.944155  0.938760  0.934035  ...  0.941141  0.957623  0.964134
# 1195  0.938760  0.934035  0.934835  ...  0.957623  0.964134  0.964023
# 1196  0.934035  0.934835  0.931394  ...  0.964134  0.964023  0.969715
# 1197  0.934835  0.931394  0.946369  ...  0.964023  0.969715  0.950778
#
#             53        54        55        56        57        58        59
# 0     0.065407  0.068830  0.072438  0.079935  0.078466  0.080345  0.084977
# 1     0.068830  0.072438  0.079935  0.078466  0.080345  0.084977  0.086279
# 2     0.072438  0.079935  0.078466  0.080345  0.084977  0.086279  0.084716
# 3     0.079935  0.078466  0.080345  0.084977  0.086279  0.084716  0.074541
# 4     0.078466  0.080345  0.084977  0.086279  0.084716  0.074541  0.078838
# ...        ...       ...       ...       ...       ...       ...       ...
# 1193  0.964134  0.964023  0.969715  0.950778  0.962944  0.961232  0.954759
# 1194  0.964023  0.969715  0.950778  0.962944  0.961232  0.954759  0.952043
# 1195  0.969715  0.950778  0.962944  0.961232  0.954759  0.952043  0.951633
# 1196  0.950778  0.962944  0.961232  0.954759  0.952043  0.951633  0.957251
# 1197  0.962944  0.961232  0.954759  0.952043  0.951633  0.957251  0.937960
#
# [1198 rows x 60 columns]

# %%
# sanity check
pd.DataFrame(y_train)
# Out:
#              0
# 0     0.086279
# 1     0.084716
# 2     0.074541
# 3     0.078838
# 4     0.072383
# ...        ...
# 1193  0.952043
# 1194  0.951633
# 1195  0.957251
# 1196  0.937960
# 1197  0.936881
#
# [1198 rows x 1 columns]

# %% [markdown]
# ### Reshaping

# %%
# reshape to the input shape required by the RNN (see Keras documentation on RNN layers input shape).
# change the 3rd dimension if there are more indicators/features
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (1198, 60, 1)

# %% [markdown]
# ## Part 2 - Building and Training the RNN

# %% [markdown]
# ### Importing the Keras libraries and packages

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %% [markdown]
# ### Initialising the RNN

# %%
rnn = Sequential()

# %% [markdown]
# ### Adding the first LSTM layer and some Dropout regularisation

# %%
rnn.add(LSTM(units=50, return_sequences=True, input_shape = (X_train.shape[1], 1)))
# In the first layer we need to include the input shape. 
# The input shape is in 3d but we only need to input the 2 dimensions: timesteps and indicators. 
# The first dimension (number of observations) is automatically taken into account later.

# %%
rnn.add(Dropout(rate=0.2))

# %% [markdown]
# ### Adding a second LSTM layer and some Dropout regularisation

# %%
rnn.add(LSTM(units = 50, return_sequences=True))
rnn.add(Dropout(rate=0.2))

# %% [markdown]
# ### Adding a third LSTM layer and some Dropout regularisation

# %%
rnn.add(LSTM(units = 50, return_sequences=True))
rnn.add(Dropout(rate=0.2))

# %% [markdown]
# ### Adding a fourth LSTM layer and some Dropout regularisation

# %%
rnn.add(LSTM(units = 50, return_sequences=False))
rnn.add(Dropout(rate=0.2))

# %% [markdown]
# ### Adding the output layer

# %%
rnn.add(Dense(units=1))

# %%
rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  lstm_1 (LSTM)               (None, 60, 50)            20200
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  lstm_2 (LSTM)               (None, 60, 50)            20200
#
#  dropout_2 (Dropout)         (None, 60, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compiling the RNN

# %%
#RMSProp is recommended by Keras as the optimizer for RNNs. We'll use Adam anyway.
rnn.compile(optimizer='Adam', loss='mean_squared_error')

# %% [markdown]
# ### Fitting the RNN to the Training set

# %%
# Also specify a batch size here.
history = rnn.fit(x = X_train, y = y_train, batch_size=32, epochs=200)
# Out:
# Epoch 1/200
# 38/38 [==============================] - 5s 34ms/step - loss: 0.0327
# Epoch 2/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.
200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0015
# Epoch 96/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0015
# Epoch 97/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0015
# Epoch 98/200
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0016
# Epoch 99/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0016
# Epoch 100/200
# 38/38 [==============================] - 1s 37ms/step - loss: 0.0015
# Epoch 101/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0016
# Epoch 102/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0015
# Epoch 103/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 104/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 105/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0013
# Epoch 106/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 107/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 108/200
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0013
# Epoch 109/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0015
# Epoch 110/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 111/200
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0014
# Epoch 112/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 113/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0013
# Epoch 114/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0015
# Epoch 115/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 116/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 117/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0014
# Epoch 118/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 119/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0012
# Epoch 120/200
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0013
# Epoch 121/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 122/200
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0013
# Epoch 123/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 124/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 125/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0012
# Epoch 126/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 127/200
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0012
# Epoch 128/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 129/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 130/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 131/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 132/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0014
# Epoch 133/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 134/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0013
# Epoch 135/200
# 38/38 [==============================] - 1s 37ms/step - loss: 0.0013
# Epoch 136/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 137/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0012
# Epoch 138/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0012
# Epoch 139/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0012
# Epoch 140/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 141/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 142/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 143/200
# 38/38 [==============================] - 1s 37ms/step - loss: 0.0012
# Epoch 144/200
# 38/38 [==============================] - 1s 37ms/step - loss: 0.0011
# Epoch 145/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 146/200
# 38/38 [==============================] - 1s 37ms/step - loss: 0.0012
# Epoch 147/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 148/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 149/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0012
# Epoch 150/200
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0011
# Epoch 151/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 152/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 153/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0010
# Epoch 154/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0010
# Epoch 155/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 156/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 157/200
# 38/38 [==============================] - 1s 35ms/step - loss: 9.3742e-04
# Epoch 158/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 159/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 160/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 161/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 162/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0010
# Epoch 163/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0010
# Epoch 164/200
# 38/38 [==============================] - 1s 38ms/step - loss: 0.0011
# Epoch 165/200
# 38/38 [==============================] - 1s 38ms/step - loss: 0.0011
# Epoch 166/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 167/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 168/200
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0011
# Epoch 169/200
# 38/38 [==============================] - 1s 35ms/step - loss: 9.8492e-04
# Epoch 170/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0010
# Epoch 171/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0015
# Epoch 172/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 173/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 174/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 175/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0010
# Epoch 176/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 177/200
# 38/38 [==============================] - 1s 36ms/step - loss: 9.9381e-04
# Epoch 178/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 179/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 180/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 181/200
# 38/38 [==============================] - 1s 36ms/step - loss: 9.9905e-04
# Epoch 182/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 183/200
# 38/38 [==============================] - 1s 35ms/step - loss: 9.6227e-04
# Epoch 184/200
# 38/38 [==============================] - 1s 36ms/step - loss: 9.6079e-04
# Epoch 185/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0010
# Epoch 186/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 187/200
# 38/38 [==============================] - 1s 34ms/step - loss: 8.6987e-04
# Epoch 188/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0010
# Epoch 189/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 190/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 191/200
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0010
# Epoch 192/200
# 38/38 [==============================] - 1s 34ms/step - loss: 9.5981e-04
# Epoch 193/200
# 38/38 [==============================] - 1s 35ms/step - loss: 9.9196e-04
# Epoch 194/200
# 38/38 [==============================] - 1s 37ms/step - loss: 9.2912e-04
# Epoch 195/200
# 38/38 [==============================] - 1s 34ms/step - loss: 0.0010
# Epoch 196/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 197/200
# 38/38 [==============================] - 1s 36ms/step - loss: 0.0010
# Epoch 198/200
# 38/38 [==============================] - 1s 35ms/step - loss: 9.0500e-04
# Epoch 199/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0010
# Epoch 200/200
# 38/38 [==============================] - 1s 35ms/step - loss: 0.0011

# %%
loss_values = history.history['loss']
epochs = range(1, len(loss_values)+1)

plt.plot(epochs, loss_values, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ## Part 3 - Making the predictions and visualising the results

# %% [markdown]
# ### Getting the real stock price of 2017

# %%
# Import the test set
test_og = pd.read_csv('data\Google_Stock_Price_Test.csv')
test = test_og.loc[:, 'Open'].values
test
# Out:
# array([778.81, 788.36, 786.08, 795.26, 806.4 , 807.86, 805.  , 807.14,
#        807.48, 807.08, 805.81, 805.12, 806.91, 807.25, 822.3 , 829.62,
#        837.81, 834.71, 814.66, 796.86])

# %%
# Normalize the test set. 
# reshape to 2d array
test = test.reshape(-1, 1)

# just use transform - we want the scaler to be fit on the train data only.
test_sc = sc.transform(test)
y_test = test_sc
test_sc
# Out:
# array([[0.92955205],
#        [0.94731751],
#        [0.94307612],
#        [0.96015329],
#        [0.98087655],
#        [0.98359253],
#        [0.97827219],
#        [0.98225314],
#        [0.98288563],
#        [0.98214153],
#        [0.979779  ],
#        [0.97849542],
#        [0.98182528],
#        [0.98245777],
#        [1.01045465],
#        [1.02407173],
#        [1.03930724],
#        [1.03354044],
#        [0.99624228],
#        [0.9631297 ]])

# %% [markdown]
# ### Getting the predicted stock price of 2017

# %%
# plot of stock price in train set
sns.lineplot(x = train_og.Date, y = train_og.Open)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
# plot of stock price in test set
sns.lineplot(x = test_og.Date, y = test_og.Open)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
# for prediction we'll need values from both the train and the test set, as we'll have to look 60 days back. 
# concatenate the two arrays.
data_sc = np.concatenate((train_sc, test_sc))

# initialize X_test as an empty list
X_test = []

# store the index of where the test set begins
index_test = data_sc.shape[0] - test_sc.shape[0]

# create the data structure with the previous 60 observations to the current timestamp
for timestamp in range(index_test, data_sc.shape[0]):
    X_test.append(data_sc[timestamp-60: timestamp, 0])

# convert to array for the RNN
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
# sanity check
pd.DataFrame(X_test)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0
# 17  0.931654  0.952545  0.888124  ...  0.982253  0.982886  0.982142  0.979779
# 18  0.952545  0.888124  0.886375  ...  0.982886  0.982142  0.979779  0.978495
# 19  0.888124  0.886375  0.870321  ...  0.982142  0.979779  0.978495  0.981825
#
#           54        55        56        57        58        59
# 0   0.954759  0.952043  0.951633  0.957251  0.937960  0.936881
# 1   0.952043  0.951633  0.957251  0.937960  0.936881  0.929552
# 2   0.951633  0.957251  0.937960  0.936881  0.929552  0.947318
# 3   0.957251  0.937960  0.936881  0.929552  0.947318  0.943076
# 4   0.937960  0.936881  0.929552  0.947318  0.943076  0.960153
# 5   0.936881  0.929552  0.947318  0.943076  0.960153  0.980877
# 6   0.929552  0.947318  0.943076  0.960153  0.980877  0.983593
# 7   0.947318  0.943076  0.960153  0.980877  0.983593  0.978272
# 8   0.943076  0.960153  0.980877  0.983593  0.978272  0.982253
# 9   0.960153  0.980877  0.983593  0.978272  0.982253  0.982886
# 10  0.980877  0.983593  0.978272  0.982253  0.982886  0.982142
# 11  0.983593  0.978272  0.982253  0.982886  0.982142  0.979779
# 12  0.978272  0.982253  0.982886  0.982142  0.979779  0.978495
# 13  0.982253  0.982886  0.982142  0.979779  0.978495  0.981825
# 14  0.982886  0.982142  0.979779  0.978495  0.981825  0.982458
# 15  0.982142  0.979779  0.978495  0.981825  0.982458  1.010455
# 16  0.979779  0.978495  0.981825  0.982458  1.010455  1.024072
# 17  0.978495  0.981825  0.982458  1.010455  1.024072  1.039307
# 18  0.981825  0.982458  1.010455  1.024072  1.039307  1.033540
# 19  0.982458  1.010455  1.024072  1.039307  1.033540  0.996242
#
# [20 rows x 60 columns]

# %%
# sanity check
pd.DataFrame(y_test)
# Out:
#            0
# 0   0.929552
# 1   0.947318
# 2   0.943076
# 3   0.960153
# 4   0.980877
# 5   0.983593
# 6   0.978272
# 7   0.982253
# 8   0.982886
# 9   0.982142
# 10  0.979779
# 11  0.978495
# 12  0.981825
# 13  0.982458
# 14  1.010455
# 15  1.024072
# 16  1.039307
# 17  1.033540
# 18  0.996242
# 19  0.963130

# %%
y_pred = rnn.predict(X_test, batch_size=32)

# %%
# inverse the normalization
y_pred = sc.inverse_transform(y_pred)
y_pred
# Out:
# array([[795.6245 ],
#        [793.21936],
#        [798.5728 ],
#        [798.7999 ],
#        [803.8666 ],
#        [812.34717],
#        [814.9211 ],
#        [813.1898 ],
#        [814.3058 ],
#        [815.42017],
#        [815.6383 ],
#        [815.08997],
#        [814.7648 ],
#        [816.06885],
#        [816.8026 ],
#        [826.4704 ],
#        [833.4189 ],
#        [839.3788 ],
#        [838.5661 ],
#        [826.1578 ]], dtype=float32)

# %% [markdown]
# ### Visualising the results

# %%
plt.plot(test_og.Date, test_og.Open, label='Actual')
plt.plot(test_og.Date, y_pred[:, 0], label='Predicted')
plt.xlabel('Date')
plt.ylabel('Open Price (€)')
plt.legend()
plt.title('Actual vs Predicted Google Stock Price')

plt.show()
